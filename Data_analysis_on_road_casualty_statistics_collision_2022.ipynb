# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/DataSets/dft-road-casualty-statistics-collision-2022.csv')
df.head()
# Out:
# <ipython-input-19-e61446fbfa83>:1: DtypeWarning: Columns (0,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/DataSets/dft-road-casualty-statistics-collision-2022.csv')
#   accident_index  accident_year accident_reference  location_easting_osgr  \
# 0  2022010352073           2022           10352073               525199.0
# 1  2022010352573           2022           10352573               546214.0
# 2  2022010352575           2022           10352575               551119.0
# 3  2022010352578           2022           10352578               528889.0
# 4  2022010352580           2022           10352580               539773.0
#
#    location_northing_osgr  longitude   latitude  police_force  \
# 0                177928.0  -0.198224  51.486454             1
# 1                179866.0   0.105042  51.498830             1
# 2                174789.0   0.173482  51.451924             1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106004 entries, 0 to 106003
# Data columns (total 36 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   accident_index                               106004 non-null  object
#  1   accident_year                                106004 non-null  int64
#  2   accident_reference                           106004 non-null  object
#  3   location_easting_osgr                        105982 non-null  float64
#  4   location_northing_osgr                       105982 non-null  float64
#  5   longitude                                    105982 non-null  float64
#  6   latitude                                     105982 non-null  float64
#  7   police_force                                 106004 non-null  int64
#  8   accident_severity                            106004 non-null  int64
# ...

# %%
df.describe()
# Out:
#        accident_year  location_easting_osgr  location_northing_osgr  \
# count       106004.0          105982.000000            1.059820e+05
# mean          2022.0          456185.969712            2.737026e+05
# std              0.0           92675.056707            1.448351e+05
# min           2022.0           79266.000000            1.050200e+04
# 25%           2022.0          393713.500000            1.748662e+05
# 50%           2022.0          463869.500000            2.120655e+05
# 75%           2022.0          529860.750000            3.810268e+05
# max           2022.0          655345.000000            1.172667e+06
#
#            longitude       latitude   police_force  accident_severity  \
# count  105982.000000  105982.000000  106004.000000      106004.000000
# mean       -1.193248      52.350694      27.499302           2.749660
# std         1.354639       1.305092      24.195187           0.466794
# min        -7.353562      49.914329       1.000000           1.000000
# ...

# %% [markdown]
# ## Data Visualization and staistical Analysis

# %%
sns.set(style="whitegrid")
plt.figure()
sns.boxplot(df['location_easting_osgr'], palette="Set2")
plt.title('Boxplot of Location Easting OSGR', fontsize=16)
plt.xlabel('Location Easting OSGR', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
# Out:
# <ipython-input-22-fe9225bdfb65>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(df['location_easting_osgr'], palette="Set2")

# %%
plt.figure()
sns.boxplot(df['location_easting_osgr'])
plt.show()

# %%
plt.figure()
sns.boxplot(df['location_northing_osgr'])
plt.show()

# %%
sns.set(style="whitegrid", palette="muted")
plt.figure()
sns.boxplot(x='longitude', data=df, color='skyblue')
plt.xlabel('Longitude', fontsize=14)
plt.title('Boxplot of Longitude Values', fontsize=16)
sns.despine(trim=True)
plt.show()

# %%
plt.figure()
sns.boxplot(df['latitude'])
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(12, 8))
sns.countplot(x='police_force', data=df, palette="Set2")
plt.title('Count of Incidents by Police Force', fontsize=16)
plt.xlabel('Police Force', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
# Out:
# <ipython-input-27-b2f9ec2acbf0>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='police_force', data=df, palette="Set2")

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['accident_severity'], bins=20, kde=True)
plt.title('Distribution of accident severity')
plt.xlabel('accident severity')
plt.ylabel('Frequency')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure()
sns.countplot(x='weather_conditions', data=df, palette="viridis")
plt.title('Count of Incidents by Weather Conditions', fontsize=16)
plt.xlabel('Weather Conditions', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(fontsize=12, rotation=45)
plt.yticks(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
ax = plt.gca()
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')
plt.show()
# Out:
# <ipython-input-29-fb036955f23e>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='weather_conditions', data=df, palette="viridis")

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['light_conditions'], bins=20, kde=True)
plt.title('Distribution of lightconditions')
plt.xlabel('lightconditions')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure()
sns.countplot(x='road_surface_conditions', data=df, palette='muted')
plt.xlabel('Road Surface Conditions', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Distribution of Accidents by Road Surface Conditions', fontsize=16)
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height()}',
                       (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center', va='baseline', fontsize=12, color='black',
                       xytext=(0, 5), textcoords='offset points')
plt.show()
# Out:
# <ipython-input-31-dc8c01dec14e>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='road_surface_conditions', data=df, palette='muted')

# %%
plt.figure()
sns.countplot(x='urban_or_rural_area', data=df, palette='Set2')
plt.xlabel('Urban or Rural Area')
plt.ylabel('Count')
plt.title('Distribution of Accidents by Urban or Rural Area')
plt.show()
# Out:
# <ipython-input-32-f0f387d1c07f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='urban_or_rural_area', data=df, palette='Set2')

# %%
plt.figure()
sns.histplot(df['did_police_officer_attend_scene_of_accident'], bins=20, kde=True)
plt.title('Distribution of did police officer attend scene of accident')
plt.xlabel('Distribution of did police officer attend scene of accident')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure()
sns.countplot(x='trunk_road_flag', data=df, palette='Set3')
plt.xlabel('Trunk Road Flag')
plt.ylabel('Count')
plt.title('Distribution of Accidents by Trunk Road Flag')
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center', va='baseline', fontsize=12, color='black', xytext=(0, 5),
                       textcoords='offset points')
plt.show()
# Out:
# <ipython-input-34-373fb6dafed0>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='trunk_road_flag', data=df, palette='Set3')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='longitude', y='latitude', hue='accident_severity', data=df, palette='viridis')
plt.title('Accident Locations')
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Decompose the time series
decomposition = seasonal_decompose(df['weather_conditions'], model='additive', period=12)
decomposition.plot()
plt.show()
