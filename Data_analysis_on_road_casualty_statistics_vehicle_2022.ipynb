# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/DataSets/dft-road-casualty-statistics-vehicle-2022.csv")
df.head()
# Out:
# <ipython-input-3-36854117f974>:1: DtypeWarning: Columns (0,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/DataSets/dft-road-casualty-statistics-vehicle-2022.csv")
#   accident_index  accident_year accident_reference  vehicle_reference  \
# 0  2022010352073           2022           10352073                  1
# 1  2022010352073           2022           10352073                  2
# 2  2022010352573           2022           10352573                  1
# 3  2022010352573           2022           10352573                  2
# 4  2022010352575           2022           10352575                  1
#
#    vehicle_type  towing_and_articulation  vehicle_manoeuvre  \
# 0            19                        0                  9
# 1             3                        0                 18
# 2             9                        0                 18
# 3             9                        0                 13
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193545 entries, 0 to 193544
# Data columns (total 28 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   accident_index                    193545 non-null  object
#  1   accident_year                     193545 non-null  int64
#  2   accident_reference                193545 non-null  object
#  3   vehicle_reference                 193545 non-null  int64
#  4   vehicle_type                      193545 non-null  int64
#  5   towing_and_articulation           193545 non-null  int64
#  6   vehicle_manoeuvre                 193545 non-null  int64
#  7   vehicle_direction_from            193545 non-null  int64
#  8   vehicle_direction_to              193545 non-null  int64
#  9   vehicle_location_restricted_lane  193545 non-null  int64
#  10  junction_location                 193545 non-null  int64
# ...

# %%
# Summary statistics for numerical columns
numerical_summary = df.describe()

# Count and describe unique values for categorical columns
categorical_summary = df.describe(include='object')

numerical_summary, categorical_summary
# Out:
# (       accident_year  vehicle_reference   vehicle_type  \
#  count       193545.0      193545.000000  193545.000000
#  mean          2022.0           1.554465      10.507985
#  std              0.0           2.812640      12.720825
#  min           2022.0           1.000000      -1.000000
#  25%           2022.0           1.000000       9.000000
#  50%           2022.0           1.000000       9.000000
#  75%           2022.0           2.000000       9.000000
#  max           2022.0         992.000000      99.000000
#
#         towing_and_articulation  vehicle_manoeuvre  vehicle_direction_from  \
#  count            193545.000000      193545.000000           193545.000000
#  mean                  0.213780          19.668196                4.365574
#  std                   1.336214          24.157514                2.765504
#  min                  -1.000000          -1.000000               -1.000000
#  25%                   0.000000           8.000000                2.000000
# ...

# %%
numeric_columns = df.select_dtypes(include=['number'])

# %%
plt.figure()
sns.histplot(df['accident_year'].dropna(), kde=True)
plt.title('Histogram of accident_year')
plt.xlabel('accident_year')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure()
sns.histplot(df['vehicle_reference'].dropna(), kde=True)
plt.title('Histogram of vehicle_reference')
plt.xlabel('vehicle_reference')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure()
sns.histplot(df['vehicle_type'].dropna(), kde=True)
plt.title('Histogram of vehicle_type')
plt.xlabel('vehicle_type')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure()
sns.histplot(df['towing_and_articulation'].dropna(), kde=True)
plt.title('Histogram of towing_and_articulation')
plt.xlabel('towing_and_articulation')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure()
sns.histplot(df['vehicle_manoeuvre'].dropna(), kde=True)
plt.title('Histogram of vehicle_manoeuvre')
plt.xlabel('vehicle_manoeuvre')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure()
sns.histplot(df['vehicle_direction_from'].dropna(), kde=True)
plt.title('Histogram of vehicle_direction_from')
plt.xlabel('vehicle_direction_from')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure()
sns.histplot(df['vehicle_direction_to'].dropna(), kde=True)
plt.title('Histogram of vehicle_direction_to')
plt.xlabel('vehicle_direction_to')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure()
sns.histplot(df['vehicle_location_restricted_lane'].dropna(), kde=True)
plt.title('Histogram of vehicle_location_restricted_lane')
plt.xlabel('vehicle_location_restricted_lane')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure()
sns.histplot(df['sex_of_driver'].dropna(), kde=True)
plt.title('Histogram of sex_of_driver')
plt.xlabel('sex_of_driver')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure()
sns.histplot(df['age_of_driver'].dropna(), kde=True)
plt.title('Histogram of age_of_driver')
plt.xlabel('age_of_driver')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure()
sns.histplot(df['age_band_of_driver'].dropna(), kde=True)
plt.title('Histogram of age_band_of_driver')
plt.xlabel('age_band_of_driver')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure()
sns.histplot(df['engine_capacity_cc'].dropna(), kde=True)
plt.title('Histogram of engine_capacity_cc')
plt.xlabel('engine_capacity_cc')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure()
sns.histplot(df['propulsion_code'].dropna(), kde=True)
plt.title('Histogram of propulsion_code')
plt.xlabel('propulsion_code')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure()
sns.histplot(df['age_of_vehicle'].dropna(), kde=True)
plt.title('Histogram of age_of_vehicle')
plt.xlabel('age_of_vehicle')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure()
sns.histplot(df['driver_imd_decile'].dropna(), kde=True)
plt.title('Histogram of driver_imd_decile')
plt.xlabel('driver_imd_decile')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure()
sns.histplot(df['driver_home_area_type'].dropna(), kde=True)
plt.title('Histogram of driver_home_area_type')
plt.xlabel('driver_home_area_type')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='age_of_driver', y='engine_capacity_cc')
plt.title('Scatter Plot between age_of_driver and engine_capacity_cc')
plt.xlabel('age_of_driver')
plt.ylabel('engine_capacity_cc')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='age_of_driver', y='age_of_vehicle')
plt.title('Scatter Plot between age_of_driver and age_of_vehicle')
plt.xlabel('age_of_driver')
plt.ylabel('age_of_vehicle')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='engine_capacity_cc', y='age_of_vehicle')
plt.title('Scatter Plot between engine_capacity_cc and age_of_vehicle')
plt.xlabel('engine_capacity_cc')
plt.ylabel('age_of_vehicle')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='accident_year', y='age_of_driver')
plt.title('Scatter Plot between accident_year and age_of_driver')
plt.xlabel('accident_year')
plt.ylabel('age_of_driver')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='accident_year', y='engine_capacity_cc')
plt.title('Scatter Plot between accident_year and engine_capacity_cc')
plt.xlabel('accident_year')
plt.ylabel('engine_capacity_cc')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='accident_year', y='age_of_vehicle')
plt.title('Scatter Plot between accident_year and age_of_vehicle')
plt.xlabel('accident_year')
plt.ylabel('age_of_vehicle')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='vehicle_manoeuvre', y='age_of_driver')
plt.title('Scatter Plot between vehicle_manoeuvre and age_of_driver')
plt.xlabel('vehicle_manoeuvre')
plt.ylabel('age_of_driver')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='vehicle_manoeuvre', y='engine_capacity_cc')
plt.title('Scatter Plot between vehicle_manoeuvre and engine_capacity_cc')
plt.xlabel('vehicle_manoeuvre')
plt.ylabel('engine_capacity_cc')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='vehicle_manoeuvre', y='age_of_vehicle')
plt.title('Scatter Plot between vehicle_manoeuvre and age_of_vehicle')
plt.xlabel('vehicle_manoeuvre')
plt.ylabel('age_of_vehicle')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='vehicle_type', y='age_of_driver')
plt.title('Scatter Plot between vehicle_type and age_of_driver')
plt.xlabel('vehicle_type')
plt.ylabel('age_of_driver')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='vehicle_type', y='engine_capacity_cc')
plt.title('Scatter Plot between vehicle_type and engine_capacity_cc')
plt.xlabel('vehicle_type')
plt.ylabel('engine_capacity_cc')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='vehicle_type', y='age_of_vehicle')
plt.title('Scatter Plot between vehicle_type and age_of_vehicle')
plt.xlabel('vehicle_type')
plt.ylabel('age_of_vehicle')
plt.show()

# %%
plt.figure()
sns.boxplot(data=df, x='sex_of_driver', y='age_of_driver')
plt.title('Box Plot of age_of_driver grouped by sex_of_driver')
plt.xlabel('sex_of_driver')
plt.ylabel('age_of_driver')
plt.show()

# %%
plt.figure()
sns.boxplot(data=df, x='sex_of_driver', y='engine_capacity_cc')
plt.title('Box Plot of engine_capacity_cc grouped by sex_of_driver')
plt.xlabel('sex_of_driver')
plt.ylabel('engine_capacity_cc')
plt.show()

# %%
plt.figure()
sns.boxplot(data=df, x='sex_of_driver', y='age_of_vehicle')
plt.title('Box Plot of age_of_vehicle grouped by sex_of_driver')
plt.xlabel('sex_of_driver')
plt.ylabel('age_of_vehicle')
plt.show()

# %%
plt.figure()
sns.boxplot(data=df, x='vehicle_type', y='age_of_driver')
plt.title('Box Plot of age_of_driver grouped by vehicle_type')
plt.xlabel('vehicle_type')
plt.ylabel('age_of_driver')
plt.show()

# %%
plt.figure()
sns.boxplot(data=df, x='vehicle_type', y='engine_capacity_cc')
plt.title('Box Plot of engine_capacity_cc grouped by vehicle_type')
plt.xlabel('vehicle_type')
plt.ylabel('engine_capacity_cc')
plt.show()

# %%
plt.figure()
sns.boxplot(data=df, x='vehicle_type', y='age_of_vehicle')
plt.title('Box Plot of age_of_vehicle grouped by vehicle_type')
plt.xlabel('vehicle_type')
plt.ylabel('age_of_vehicle')
plt.show()

# %%
plt.figure()
sns.boxplot(data=df, x='driver_home_area_type', y='age_of_driver')
plt.title('Box Plot of age_of_driver grouped by driver_home_area_type')
plt.xlabel('driver_home_area_type')
plt.ylabel('age_of_driver')
plt.show()

# %%
plt.figure()
sns.boxplot(data=df, x='driver_home_area_type', y='age_of_vehicle')
plt.title('Box Plot of age_of_vehicle grouped by driver_home_area_type')
plt.xlabel('driver_home_area_type')
plt.ylabel('age_of_vehicle')
plt.show()
