# %%
import pandas as pd
df = pd.read_csv('/content/Student_Marks.csv')

# %%
df.head()
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299

# %%
df.isnull().sum()
# Out:
# number_courses    0
# time_study        0
# Marks             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
x = df[['number_courses','time_study']]
y = df['Marks']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.15)

# %%
print("Training Data Size : ", len(x_train))
print("Testing  Data Size : ", len(x_test))
# Out:
# Training Data Size :  85
# Testing  Data Size :  15

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.922375771130336

# %%
y_pred =  model.predict(x_test)
y_pred
# Out:
# array([17.30947557, 32.25902182, 13.36434022, 40.08465941, 23.49902542,
#        23.36305336, 22.82798522,  7.97662731, 32.63875263, 23.5795736 ,
#        40.21008628,  7.36810597, 31.17814577, 45.96659568, 29.87499048,
#        23.33792908, 29.30194405, 12.95066503, 14.23618015, 21.45847172])

# %%
pd.DataFrame({"Actual Test Values": y_test, "Predicted Test Values": y_pred})
# Out:
#     Actual Test Values  Predicted Test Values
# 2               13.811              17.309476
# 23              28.043              32.259022
# 22              12.209              13.364340
# 77              38.278              40.084659
# 42              19.771              23.499025
# 49              19.106              23.363053
# 0               19.202              22.827985
# 68               8.920               7.976627
# 99              32.357              32.638753
# 62              19.590              23.579574
# 50              40.602              40.210086
# 73               7.014               7.368106
# 6               29.889              31.178146
# 39              51.142              45.966596
# 66              27.569              29.874990
# 95              19.128              23.337929
# 19              25.133              29.301944
# 32              15.038              12.950665
# 14              11.397              14.236180
# 5               17.822              21.458472
